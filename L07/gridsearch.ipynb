# %% [markdown]
# # ITMAL Exercise
#
# REVISIONS| |
# ---------| |
# 2018-0301| CEF, initial.
# 2018-0305| CEF, updated.
# 2018-0306| CEF, updated and spell checked.
# 2018-0306| CEF, major overhaul of functions.
# 2018-0306| CEF, fixed problem with MNIST load and Keras.
# 2018-0307| CEF, modified report functions and changed Qc+d.
# 2018-0311| CEF, updated Qd.
# 2018-0312| CEF, added grid and random search figs and added bullets to Qd.
#
# ## Hyperparameters and Gridsearch
#
# When instantiating a Scikit-learn model in python most or all constructor parameters have _default_ values. These values are not part of the internal model and are hence called ___hyperparametes___---in contrast to _normal_ model parameters, say the weights, $\mathbf w$, for an `SGD` model.
#
# An example could be the python constructor for the support-vector classifier `sklearn.svm.SVC`, with, say the `kernel` hyperparameter having the default value `'rbf'`. If you should choose, what would you set it to other than `'rbf'`?
#
# ```python
# class sklearn.svm.SVC(
#     C=1.0,
#     kernel=’rbf’,
#     degree=3,
#     gamma=’auto_deprecated’,
#     coef0=0.0,
#     shrinking=True,
#     probability=False,
#     tol=0.001,
#     cache_size=200,
#     class_weight=None,
#     verbose=False,
#     max_iter=-1,
#     decision_function_shape=’ovr’,
#     random_state=None
#   )
# ```
#
# The default values might be sensible a general starting point, but for your data, you might want to optimize the hyperparameters to yield a better result.
#
# To be able to set `kernel` to a sensible value you need to go into the documentation for the `SVC` and understand what the kernel represents and what values it can be set to, and you need to understand the consequences of setting `kernel` to something different than the default...and the story repeats for every other hyperparameter!
#
# An alternative is just to __brute-force__ a search of interesting hyperparameters, an choosing the 'best' parameters according to a fit-predict and some performance metric, say 'f1'.
#
# Now, you just pick out some hyperparameters, that you figure are important, set then to a suitable range, say
#
# ```python
#     'kernel':('linear', 'rbf'),
#     'C':[1, 10]
# ```
# and fire up a full (grid) search on this hyperparameter set, that will try out all combination of `kernel` and `C` for the model, and then prints the hyperparameter set with the highest score...
#
# <img src="Figs/gridsearch.png" style="width:300px">
# <small><em>
#     <center> Conceptual graphical view of grid search for two distinct hyperparameters. </center>
#     <center> Notice that you would normally search hyperparameters like `alpha` with an exponential range, say [0.01, 0.1, 1, 10] or similar.</center>
# </em></small>
#
# The demo code below sets up some of our well known 'hello-world' data and run a _grid search_ on a particular model, here a _support-vector classifier_ (SVC)
#
# Other models and datasets  ('mnist', 'iris', 'moon') can also be examined.
#
#
# ### Qa Explain GridSearchCV
#
# There are two code cells below: 1:) function setup, 2) the actual grid-search.
#
# Review the code cells and write a __short__ summary. Mainly focus on __cell 2__, but dig into cell 1 if you find it interesting (notice the use of local-function, a nifty feature in python).
#
# In detail, examine the lines:
#
# ```python
# grid_tuned = GridSearchCV(model, tuning_parameters, ..
# grid_tuned.fit(X_train, y_train)
# ..
# FullReport(grid_tuned , X_test, y_test, time_gridsearch)
# ```
# and write a short description of how the `GridSeachCV` works: explain how the search parameter set is created and the overall search mechanism (without going into to much detail)
#
# What role does the parameter `scoring='f1_micro'` play in the `GridSearchCV`, and what does `n_jobs=-1` mean?

# %%
# TODO: Qa, code review..cell 1) function setup
import sys,os
sys.path.append(os.path.expanduser('..\MachineLearning'))

from time import time
import numpy as np

from sklearn import svm
from sklearn.linear_model import SGDClassifier

from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split
from sklearn.metrics import classification_report, f1_score
from sklearn import datasets

#from libitmal import utils as itmalutils
from libitmal import dataloaders_v2 as itmaldataloaders

currmode="N/A" # GLOBAL var!

def SearchReport(model): 
    
    def GetBestModelCTOR(model, best_params):
        def GetParams(best_params):
            r=""          
            for key in sorted(best_params):
                value = best_params[key]
                t = "'" if str(type(value))=="<class 'str'>" else ""
                if len(r)>0:
                    r += ','
                r += f'{key}={t}{value}{t}'  
            return r            
        try:
            p = GetParams(best_params)
            return type(model).__name__ + '(' + p + ')' 
        except:
            return "N/A(1)"
        
    print("\nBest model set found on train set:")
    print()
    print(f"\tbest parameters={model.best_params_}")
    print(f"\tbest '{model.scoring}' score={model.best_score_}")
    print(f"\tbest index={model.best_index_}")
    print()
    print(f"Best estimator CTOR:")
    print(f"\t{model.best_estimator_}")
    print()
    try:
        print(f"Grid scores ('{model.scoring}') on development set:")
        means = model.cv_results_['mean_test_score']
        stds  = model.cv_results_['std_test_score']
        i=0
        for mean, std, params in zip(means, stds, model.cv_results_['params']):
            print("\t[%2d]: %0.3f (+/-%0.03f) for %r" % (i, mean, std * 2, params))
            i += 1
    except:
        print("WARNING: the random search do not provide means/stds")
    
    global currmode                
    assert "f1_micro"==str(model.scoring), f"come on, we need to fix the scoring to be able to compare model-fits! Your scoreing={str(model.scoring)}...remember to add scoring='f1_micro' to the search"   
    return f"best: dat={currmode}, score={model.best_score_:0.5f}, model={GetBestModelCTOR(model.estimator,model.best_params_)}", model.best_estimator_ 

def ClassificationReport(model, X_test, y_test, target_names=None):
    assert X_test.shape[0]==y_test.shape[0]
    print("\nDetailed classification report:")
    print("\tThe model is trained on the full development set.")
    print("\tThe scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, model.predict(X_test)                 
    print(classification_report(y_true, y_pred, target_names))
    print()
    
def FullReport(model, X_test, y_test, t):
    print(f"SEARCH TIME: {t:0.2f} sec")
    beststr, bestmodel = SearchReport(model)
    ClassificationReport(model, X_test, y_test)    
    print(f"CTOR for best model: {bestmodel}\n")
    print(f"{beststr}\n")
    return beststr, bestmodel
    
def LoadAndSetupData(mode, test_size=0.3):
    assert test_size>=0.0 and test_size<=1.0
    
    def ShapeToString(Z):
        n = Z.ndim
        s = "("
        for i in range(n):
            s += f"{Z.shape[i]:5d}"
            if i+1!=n:
                s += ";"
        return s+")"

    global currmode
    currmode=mode
    print(f"DATA: {currmode}..")
    
    if mode=='moon':
        X, y = itmaldataloaders.MOON_GetDataSet(n_samples=5000, noise=0.2)
        itmaldataloaders.MOON_Plot(X, y)
    elif mode=='mnist':
        X, y = itmaldataloaders.MNIST_GetDataSet(fetchmode=False)
        if X.ndim==3:
            X=np.reshape(X, (X.shape[0], -1))
    elif mode=='iris':
        X, y = itmaldataloaders.IRIS_GetDataSet()
    else:
        raise ValueError(f"could not load data for that particular mode='{mode}'")
        
    print(f'  org. data:  X.shape      ={ShapeToString(X)}, y.shape      ={ShapeToString(y)}')

    assert X.ndim==2
    assert X.shape[0]==y.shape[0]
    assert y.ndim==1 or (y.ndim==2 and y.shape[1]==0)    
    
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, random_state=0, shuffle=True
    )
    
    print(f'  train data: X_train.shape={ShapeToString(X_train)}, y_train.shape={ShapeToString(y_train)}')
    print(f'  test data:  X_test.shape ={ShapeToString(X_test)}, y_test.shape ={ShapeToString(y_test)}')
    print()
    
    return X_train, X_test, y_train, y_test

print('OK')
# Out:
# OK

# %%
# TODO: Qa, code review..cell 2) the actual grid-search

# Setup data
X_train, X_test, y_train, y_test = LoadAndSetupData('iris') # or 'moon', or 'mnist'

# Setup search parameters
model = svm.SVC(gamma="scale")

tuning_parameters = {
    'kernel':('linear', 'rbf'), 
    'C':[1, 10]
}

CV=5
VERBOSE=0

# Run GridSearchCV for the model
start = time()
grid_tuned = GridSearchCV(model, tuning_parameters, cv=CV, scoring='f1_micro', verbose=VERBOSE, n_jobs=-1, iid=True)
grid_tuned.fit(X_train, y_train)
t = time()-start

# Report result
b0, m0= FullReport(grid_tuned , X_test, y_test, t)
print('OK')
# Out:
# DATA: iris..
#   org. data:  X.shape      =(  150;    4), y.shape      =(  150)
#   train data: X_train.shape=(  105;    4), y_train.shape=(  105)
#   test data:  X_test.shape =(   45;    4), y_test.shape =(   45)
#
# SEARCH TIME: 1.66 sec
#
# Best model set found on train set:
#
# 	best parameters={'C': 1, 'kernel': 'linear'}
# 	best 'f1_micro' score=0.9714285714285714
# 	best index=0
#
# Best estimator CTOR:
# 	SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# Grid scores ('f1_micro') on development set:
# 	[ 0]: 0.971 (+/-0.048) for {'C': 1, 'kernel': 'linear'}
# 	[ 1]: 0.962 (+/-0.072) for {'C': 1, 'kernel': 'rbf'}
# 	[ 2]: 0.952 (+/-0.084) for {'C': 10, 'kernel': 'linear'}
# 	[ 3]: 0.962 (+/-0.072) for {'C': 10, 'kernel': 'rbf'}
#
# Detailed classification report:
# 	The model is trained on the full development set.
# 	The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.94      0.97        18
#            2       0.92      1.00      0.96        11
#
#    micro avg       0.98      0.98      0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
#
#
# CTOR for best model: SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
#
# best: dat=iris, score=0.97143, model=SVC(C=1,kernel='linear')
#
# OK

# %% [markdown]
# grid search cv bruges til at pegle sig ind på de bedste parameter til en model, ved at prøve sig frem i mange forsøg, dog kan nogle parametre vælges i forvejen.
#
# scoring f1_micro er den score der bruges til at regulere med.
# n_jobs=-1 kører parralelt.

# %% [markdown]
# ### Qb Hyperparameter Grid Search using an SDG classifier
#
# Now, replace the `svm.SVC` model with an `SGDClassifier` and a suitable set of the hyperparameters for that model.
#
# You need at least four or five different hyperparameters from the `SDG` in the search-space before it begins to take considerable compute time doing the full grid search.

# %%
# TODO: Qb..
model = SGDClassifier()



tuning_parameters = {
    'n_iter_no_change':np.arange(1, 17, 1), 
    'alpha': np.arange(0.5, 17, 0.5),
    'average': (True,False)
}

CV=5
VERBOSE=0

# Run GridSearchCV for the model
start = time()
grid_tuned = GridSearchCV(model, tuning_parameters, cv=CV, scoring='f1_micro', verbose=VERBOSE, n_jobs=-1, iid=True)
grid_tuned.fit(X_train, y_train)
t = time()-start

# Report result
b0, m0= FullReport(grid_tuned , X_test, y_test, t)
print('OK')
# Out:
# SEARCH TIME: 4.87 sec
#
# Best model set found on train set:
#
# 	best parameters={'alpha': 0.5, 'average': True, 'n_iter_no_change': 4}
# 	best 'f1_micro' score=0.7523809523809524
# 	best index=3
#
# Best estimator CTOR:
# 	SGDClassifier(alpha=0.5, average=True, class_weight=None,
#        early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#        l1_ratio=0.15, learning_rate='optimal', loss='hinge', max_iter=None,
#        n_iter=None, n_iter_no_change=4, n_jobs=None, penalty='l2',
#        power_t=0.5, random_state=None, shuffle=True, tol=None,
#        validation_fraction=0.1, verbose=0, warm_start=False)
#
# Grid scores ('f1_micro') on development set:
# 	[ 0]: 0.695 (+/-0.031) for {'alpha': 0.5, 'average': True, 'n_iter_no_change': 1}
# 	[ 1]: 0.695 (+/-0.031) for {'alpha': 0.5, 'average': True, 'n_iter_no_change': 2}
# 	[ 2]: 0.695 (+/-0.031) for {'alpha': 0.5, 'average': True, 'n_iter_no_change': 3}
# 	[ 3]: 0.752 (+/-0.126) for {'alpha': 0.5, 'average': True, 'n_iter_no_change': 4}
# 	[ 4]: 0.705 (+/-0.062) for {'alpha': 0.5, 'average': True, 'n_iter_no_change': 5}
# 	[ 5]: 0.695 (+/-0.031) for {'alpha': 0.5, 'average': True, 'n_iter_no_change': 6}
# 	[ 6]: 0.695 (+/-0.031) for {'alpha': 0.5, 'average': True, 'n_iter_no_change': 7}
# 	[ 7]: 0.695 (+/-0.031) for {'alpha': 0.5, 'average': True, 'n_iter_no_change': 8}
# 	[ 8]: 0.714 (+/-0.098) for {'alpha': 0.5, 'average': True, 'n_iter_no_change': 9}
# 	[ 9]: 0.695 (+/-0.031) for {'alpha': 0.5, 'average': True, 'n_iter_no_change': 10}
# 	[10]: 0.705 (+/-0.036) for {'alpha': 0.5, 'average': True, 'n_iter_no_change': 11}
# 	[11]: 0.695 (+/-0.031) for {'alpha': 0.5, 'average': True, 'n_iter_no_change': 12}
# 	[12]: 0.724 (+/-0.105) for {'alpha': 0.5, 'average': True, 'n_iter_no_change': 13}
# 	[13]: 0.724 (+/-0.076) for {'alpha': 0.5, 'average': True, 'n_iter_no_change': 14}
# 	[14]: 0.695 (+/-0.031) for {'alpha': 0.5, 'average': True, 'n_iter_no_change': 15}
# 	[15]: 0.714 (+/-0.066) for {'alpha': 0.5, 'average': True, 'n_iter_no_change': 16}
# 	[16]: 0.695 (+/-0.031) for {'alpha': 0.5, 'average': False, 'n_iter_no_change': 1}
# 	[17]: 0.695 (+/-0.031) for {'alpha': 0.5, 'average': False, 'n_iter_no_change': 2}
# 	[18]: 0.724 (+/-0.101) for {'alpha': 0.5, 'average': False, 'n_iter_no_change': 3}
# 	[19]: 0.695 (+/-0.031) for {'alpha': 0.5, 'average': False, 'n_iter_no_change': 4}
# 	[20]: 0.695 (+/-0.031) for {'alpha': 0.5, 'average': False, 'n_iter_no_change': 5}
# 	[21]: 0.676 (+/-0.062) for {'alpha': 0.5, 'average': False, 'n_iter_no_change': 6}
# 	[22]: 0.695 (+/-0.031) for {'alpha': 0.5, 'average': False, 'n_iter_no_change': 7}
# 	[23]: 0.714 (+/-0.111) for {'alpha': 0.5, 'average': False, 'n_iter_no_change': 8}
# 	[24]: 0.695 (+/-0.031) for {'alpha': 0.5, 'average': False, 'n_iter_no_change': 9}
# 	[25]: 0.695 (+/-0.031) for {'alpha': 0.5, 'average': False, 'n_iter_no_change': 10}
# 	[26]: 0.657 (+/-0.164) for {'alpha': 0.5, 'average': False, 'n_iter_no_change': 11}
# 	[27]: 0.695 (+/-0.031) for {'alpha': 0.5, 'average': False, 'n_iter_no_change': 12}
# 	[28]: 0.695 (+/-0.031) for {'alpha': 0.5, 'average': False, 'n_iter_no_change': 13}
# 	[29]: 0.695 (+/-0.031) for {'alpha': 0.5, 'average': False, 'n_iter_no_change': 14}
# 	[30]: 0.686 (+/-0.059) for {'alpha': 0.5, 'average': False, 'n_iter_no_change': 15}
# 	[31]: 0.752 (+/-0.193) for {'alpha': 0.5, 'average': False, 'n_iter_no_change': 16}
# 	[32]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': True, 'n_iter_no_change': 1}
# 	[33]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': True, 'n_iter_no_change': 2}
# 	[34]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': True, 'n_iter_no_change': 3}
# 	[35]: 0.705 (+/-0.036) for {'alpha': 1.0, 'average': True, 'n_iter_no_change': 4}
# 	[36]: 0.705 (+/-0.036) for {'alpha': 1.0, 'average': True, 'n_iter_no_change': 5}
# 	[37]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': True, 'n_iter_no_change': 6}
# 	[38]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': True, 'n_iter_no_change': 7}
# 	[39]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': True, 'n_iter_no_change': 8}
# 	[40]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': True, 'n_iter_no_change': 9}
# 	[41]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': True, 'n_iter_no_change': 10}
# 	[42]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': True, 'n_iter_no_change': 11}
# 	[43]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': True, 'n_iter_no_change': 12}
# 	[44]: 0.705 (+/-0.036) for {'alpha': 1.0, 'average': True, 'n_iter_no_change': 13}
# 	[45]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': True, 'n_iter_no_change': 14}
# 	[46]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': True, 'n_iter_no_change': 15}
# 	[47]: 0.705 (+/-0.036) for {'alpha': 1.0, 'average': True, 'n_iter_no_change': 16}
# 	[48]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': False, 'n_iter_no_change': 1}
# 	[49]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': False, 'n_iter_no_change': 2}
# 	[50]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': False, 'n_iter_no_change': 3}
# 	[51]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': False, 'n_iter_no_change': 4}
# 	[52]: 0.705 (+/-0.042) for {'alpha': 1.0, 'average': False, 'n_iter_no_change': 5}
# 	[53]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': False, 'n_iter_no_change': 6}
# 	[54]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': False, 'n_iter_no_change': 7}
# 	[55]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': False, 'n_iter_no_change': 8}
# 	[56]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': False, 'n_iter_no_change': 9}
# 	[57]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': False, 'n_iter_no_change': 10}
# 	[58]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': False, 'n_iter_no_change': 11}
# 	[59]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': False, 'n_iter_no_change': 12}
# 	[60]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': False, 'n_iter_no_change': 13}
# 	[61]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': False, 'n_iter_no_change': 14}
# 	[62]: 0.695 (+/-0.031) for {'alpha': 1.0, 'average': False, 'n_iter_no_change': 15}
# 	[63]: 0.752 (+/-0.249) for {'alpha': 1.0, 'average': False, 'n_iter_no_change': 16}
# 	[64]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': True, 'n_iter_no_change': 1}
# 	[65]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': True, 'n_iter_no_change': 2}
# 	[66]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': True, 'n_iter_no_change': 3}
# 	[67]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': True, 'n_iter_no_change': 4}
# 	[68]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': True, 'n_iter_no_change': 5}
# 	[69]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': True, 'n_iter_no_change': 6}
# 	[70]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': True, 'n_iter_no_change': 7}
# 	[71]: 0.705 (+/-0.036) for {'alpha': 1.5, 'average': True, 'n_iter_no_change': 8}
# 	[72]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': True, 'n_iter_no_change': 9}
# 	[73]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': True, 'n_iter_no_change': 10}
# 	[74]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': True, 'n_iter_no_change': 11}
# 	[75]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': True, 'n_iter_no_change': 12}
# 	[76]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': True, 'n_iter_no_change': 13}
# 	[77]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': True, 'n_iter_no_change': 14}
# 	[78]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': True, 'n_iter_no_change': 15}
# 	[79]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': True, 'n_iter_no_change': 16}
# 	[80]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': False, 'n_iter_no_change': 1}
# 	[81]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': False, 'n_iter_no_change': 2}
# 	[82]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': False, 'n_iter_no_change': 3}
# 	[83]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': False, 'n_iter_no_change': 4}
# 	[84]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': False, 'n_iter_no_change': 5}
# 	[85]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': False, 'n_iter_no_change': 6}
# 	[86]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': False, 'n_iter_no_change': 7}
# 	[87]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': False, 'n_iter_no_change': 8}
# 	[88]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': False, 'n_iter_no_change': 9}
# 	[89]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': False, 'n_iter_no_change': 10}
# 	[90]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': False, 'n_iter_no_change': 11}
# 	[91]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': False, 'n_iter_no_change': 12}
# 	[92]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': False, 'n_iter_no_change': 13}
# 	[93]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': False, 'n_iter_no_change': 14}
# 	[94]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': False, 'n_iter_no_change': 15}
# 	[95]: 0.695 (+/-0.031) for {'alpha': 1.5, 'average': False, 'n_iter_no_change': 16}
# 	[96]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': True, 'n_iter_no_change': 1}
# 	[97]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': True, 'n_iter_no_change': 2}
# 	[98]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': True, 'n_iter_no_change': 3}
# 	[99]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': True, 'n_iter_no_change': 4}
# 	[100]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': True, 'n_iter_no_change': 5}
# 	[101]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': True, 'n_iter_no_change': 6}
# 	[102]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': True, 'n_iter_no_change': 7}
# 	[103]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': True, 'n_iter_no_change': 8}
# 	[104]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': True, 'n_iter_no_change': 9}
# 	[105]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': True, 'n_iter_no_change': 10}
# 	[106]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': True, 'n_iter_no_change': 11}
# 	[107]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': True, 'n_iter_no_change': 12}
# 	[108]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': True, 'n_iter_no_change': 13}
# 	[109]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': True, 'n_iter_no_change': 14}
# 	[110]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': True, 'n_iter_no_change': 15}
# 	[111]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': True, 'n_iter_no_change': 16}
# 	[112]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': False, 'n_iter_no_change': 1}
# 	[113]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': False, 'n_iter_no_change': 2}
# 	[114]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': False, 'n_iter_no_change': 3}
# 	[115]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': False, 'n_iter_no_change': 4}
# 	[116]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': False, 'n_iter_no_change': 5}
# 	[117]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': False, 'n_iter_no_change': 6}
# 	[118]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': False, 'n_iter_no_change': 7}
# 	[119]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': False, 'n_iter_no_change': 8}
# 	[120]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': False, 'n_iter_no_change': 9}
# 	[121]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': False, 'n_iter_no_change': 10}
# 	[122]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': False, 'n_iter_no_change': 11}
# 	[123]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': False, 'n_iter_no_change': 12}
# 	[124]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': False, 'n_iter_no_change': 13}
# 	[125]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': False, 'n_iter_no_change': 14}
# 	[126]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': False, 'n_iter_no_change': 15}
# 	[127]: 0.695 (+/-0.031) for {'alpha': 2.0, 'average': False, 'n_iter_no_change': 16}
# 	[128]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': True, 'n_iter_no_change': 1}
# 	[129]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': True, 'n_iter_no_change': 2}
# 	[130]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': True, 'n_iter_no_change': 3}
# 	[131]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': True, 'n_iter_no_change': 4}
# 	[132]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': True, 'n_iter_no_change': 5}
# 	[133]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': True, 'n_iter_no_change': 6}
# 	[134]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': True, 'n_iter_no_change': 7}
# 	[135]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': True, 'n_iter_no_change': 8}
# 	[136]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': True, 'n_iter_no_change': 9}
# 	[137]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': True, 'n_iter_no_change': 10}
# 	[138]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': True, 'n_iter_no_change': 11}
# 	[139]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': True, 'n_iter_no_change': 12}
# 	[140]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': True, 'n_iter_no_change': 13}
# 	[141]: 0.705 (+/-0.062) for {'alpha': 2.5, 'average': True, 'n_iter_no_change': 14}
# 	[142]: 0.705 (+/-0.062) for {'alpha': 2.5, 'average': True, 'n_iter_no_change': 15}
# 	[143]: 0.714 (+/-0.066) for {'alpha': 2.5, 'average': True, 'n_iter_no_change': 16}
# 	[144]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': False, 'n_iter_no_change': 1}
# 	[145]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': False, 'n_iter_no_change': 2}
# 	[146]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': False, 'n_iter_no_change': 3}
# 	[147]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': False, 'n_iter_no_change': 4}
# 	[148]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': False, 'n_iter_no_change': 5}
# 	[149]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': False, 'n_iter_no_change': 6}
# 	[150]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': False, 'n_iter_no_change': 7}
# 	[151]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': False, 'n_iter_no_change': 8}
# 	[152]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': False, 'n_iter_no_change': 9}
# 	[153]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': False, 'n_iter_no_change': 10}
# 	[154]: 0.705 (+/-0.036) for {'alpha': 2.5, 'average': False, 'n_iter_no_change': 11}
# 	[155]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': False, 'n_iter_no_change': 12}
# 	[156]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': False, 'n_iter_no_change': 13}
# 	[157]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': False, 'n_iter_no_change': 14}
# 	[158]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': False, 'n_iter_no_change': 15}
# 	[159]: 0.695 (+/-0.031) for {'alpha': 2.5, 'average': False, 'n_iter_no_change': 16}
# 	[160]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': True, 'n_iter_no_change': 1}
# 	[161]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': True, 'n_iter_no_change': 2}
# 	[162]: 0.686 (+/-0.058) for {'alpha': 3.0, 'average': True, 'n_iter_no_change': 3}
# 	[163]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': True, 'n_iter_no_change': 4}
# 	[164]: 0.705 (+/-0.036) for {'alpha': 3.0, 'average': True, 'n_iter_no_change': 5}
# 	[165]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': True, 'n_iter_no_change': 6}
# 	[166]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': True, 'n_iter_no_change': 7}
# 	[167]: 0.705 (+/-0.036) for {'alpha': 3.0, 'average': True, 'n_iter_no_change': 8}
# 	[168]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': True, 'n_iter_no_change': 9}
# 	[169]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': True, 'n_iter_no_change': 10}
# 	[170]: 0.714 (+/-0.059) for {'alpha': 3.0, 'average': True, 'n_iter_no_change': 11}
# 	[171]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': True, 'n_iter_no_change': 12}
# 	[172]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': True, 'n_iter_no_change': 13}
# 	[173]: 0.686 (+/-0.058) for {'alpha': 3.0, 'average': True, 'n_iter_no_change': 14}
# 	[174]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': True, 'n_iter_no_change': 15}
# 	[175]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': True, 'n_iter_no_change': 16}
# 	[176]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': False, 'n_iter_no_change': 1}
# 	[177]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': False, 'n_iter_no_change': 2}
# 	[178]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': False, 'n_iter_no_change': 3}
# 	[179]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': False, 'n_iter_no_change': 4}
# 	[180]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': False, 'n_iter_no_change': 5}
# 	[181]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': False, 'n_iter_no_change': 6}
# 	[182]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': False, 'n_iter_no_change': 7}
# 	[183]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': False, 'n_iter_no_change': 8}
# 	[184]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': False, 'n_iter_no_change': 9}
# 	[185]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': False, 'n_iter_no_change': 10}
# 	[186]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': False, 'n_iter_no_change': 11}
# 	[187]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': False, 'n_iter_no_change': 12}
# 	[188]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': False, 'n_iter_no_change': 13}
# 	[189]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': False, 'n_iter_no_change': 14}
# 	[190]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': False, 'n_iter_no_change': 15}
# 	[191]: 0.695 (+/-0.031) for {'alpha': 3.0, 'average': False, 'n_iter_no_change': 16}
# 	[192]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': True, 'n_iter_no_change': 1}
# 	[193]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': True, 'n_iter_no_change': 2}
# 	[194]: 0.667 (+/-0.135) for {'alpha': 3.5, 'average': True, 'n_iter_no_change': 3}
# 	[195]: 0.714 (+/-0.059) for {'alpha': 3.5, 'average': True, 'n_iter_no_change': 4}
# 	[196]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': True, 'n_iter_no_change': 5}
# 	[197]: 0.686 (+/-0.058) for {'alpha': 3.5, 'average': True, 'n_iter_no_change': 6}
# 	[198]: 0.705 (+/-0.062) for {'alpha': 3.5, 'average': True, 'n_iter_no_change': 7}
# 	[199]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': True, 'n_iter_no_change': 8}
# 	[200]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': True, 'n_iter_no_change': 9}
# 	[201]: 0.705 (+/-0.042) for {'alpha': 3.5, 'average': True, 'n_iter_no_change': 10}
# 	[202]: 0.705 (+/-0.036) for {'alpha': 3.5, 'average': True, 'n_iter_no_change': 11}
# 	[203]: 0.686 (+/-0.058) for {'alpha': 3.5, 'average': True, 'n_iter_no_change': 12}
# 	[204]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': True, 'n_iter_no_change': 13}
# 	[205]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': True, 'n_iter_no_change': 14}
# 	[206]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': True, 'n_iter_no_change': 15}
# 	[207]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': True, 'n_iter_no_change': 16}
# 	[208]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': False, 'n_iter_no_change': 1}
# 	[209]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': False, 'n_iter_no_change': 2}
# 	[210]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': False, 'n_iter_no_change': 3}
# 	[211]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': False, 'n_iter_no_change': 4}
# 	[212]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': False, 'n_iter_no_change': 5}
# 	[213]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': False, 'n_iter_no_change': 6}
# 	[214]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': False, 'n_iter_no_change': 7}
# 	[215]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': False, 'n_iter_no_change': 8}
# 	[216]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': False, 'n_iter_no_change': 9}
# 	[217]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': False, 'n_iter_no_change': 10}
# 	[218]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': False, 'n_iter_no_change': 11}
# 	[219]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': False, 'n_iter_no_change': 12}
# 	[220]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': False, 'n_iter_no_change': 13}
# 	[221]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': False, 'n_iter_no_change': 14}
# 	[222]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': False, 'n_iter_no_change': 15}
# 	[223]: 0.695 (+/-0.031) for {'alpha': 3.5, 'average': False, 'n_iter_no_change': 16}
# 	[224]: 0.724 (+/-0.105) for {'alpha': 4.0, 'average': True, 'n_iter_no_change': 1}
# 	[225]: 0.695 (+/-0.031) for {'alpha': 4.0, 'average': True, 'n_iter_no_change': 2}
# 	[226]: 0.705 (+/-0.036) for {'alpha': 4.0, 'average': True, 'n_iter_no_change': 3}
# 	[227]: 0.705 (+/-0.062) for {'alpha': 4.0, 'average': True, 'n_iter_no_change': 4}
# 	[228]: 0.676 (+/-0.062) for {'alpha': 4.0, 'average': True, 'n_iter_no_change': 5}
# 	[229]: 0.686 (+/-0.058) for {'alpha': 4.0, 'average': True, 'n_iter_no_change': 6}
# 	[230]: 0.695 (+/-0.084) for {'alpha': 4.0, 'average': True, 'n_iter_no_change': 7}
# 	[231]: 0.695 (+/-0.031) for {'alpha': 4.0, 'average': True, 'n_iter_no_change': 8}
# 	[232]: 0.695 (+/-0.031) for {'alpha': 4.0, 'average': True, 'n_iter_no_change': 9}
# 	[233]: 0.676 (+/-0.062) for {'alpha': 4.0, 'average': True, 'n_iter_no_change': 10}
# 	[234]: 0.714 (+/-0.098) for {'alpha': 4.0, 'average': True, 'n_iter_no_change': 11}
# 	[235]: 0.695 (+/-0.031) for {'alpha': 4.0, 'average': True, 'n_iter_no_change': 12}
# 	[236]: 0.695 (+/-0.031) for {'alpha': 4.0, 'average': True, 'n_iter_no_change': 13}
# 	[237]: 0.695 (+/-0.031) for {'alpha': 4.0, 'average': True, 'n_iter_no_change': 14}
# 	[238]: 0.695 (+/-0.084) for {'alpha': 4.0, 'average': True, 'n_iter_no_change': 15}
# 	[239]: 0.695 (+/-0.068) for {'alpha': 4.0, 'average': True, 'n_iter_no_change': 16}
# 	[240]: 0.695 (+/-0.031) for {'alpha': 4.0, 'average': False, 'n_iter_no_change': 1}
# 	[241]: 0.695 (+/-0.031) for {'alpha': 4.0, 'average': False, 'n_iter_no_change': 2}
# 	[242]: 0.695 (+/-0.031) for {'alpha': 4.0, 'average': False, 'n_iter_no_change': 3}
# 	[243]: 0.695 (+/-0.031) for {'alpha': 4.0, 'average': False, 'n_iter_no_change': 4}
# 	[244]: 0.695 (+/-0.031) for {'alpha': 4.0, 'average': False, 'n_iter_no_change': 5}
# 	[245]: 0.695 (+/-0.031) for {'alpha': 4.0, 'average': False, 'n_iter_no_change': 6}
# 	[246]: 0.695 (+/-0.031) for {'alpha': 4.0, 'average': False, 'n_iter_no_change': 7}
# 	[247]: 0.714 (+/-0.059) for {'alpha': 4.0, 'average': False, 'n_iter_no_change': 8}
# 	[248]: 0.695 (+/-0.031) for {'alpha': 4.0, 'average': False, 'n_iter_no_change': 9}
# 	[249]: 0.695 (+/-0.031) for {'alpha': 4.0, 'average': False, 'n_iter_no_change': 10}
# 	[250]: 0.695 (+/-0.031) for {'alpha': 4.0, 'average': False, 'n_iter_no_change': 11}
# 	[251]: 0.695 (+/-0.031) for {'alpha': 4.0, 'average': False, 'n_iter_no_change': 12}
# 	[252]: 0.695 (+/-0.031) for {'alpha': 4.0, 'average': False, 'n_iter_no_change': 13}
# 	[253]: 0.695 (+/-0.031) for {'alpha': 4.0, 'average': False, 'n_iter_no_change': 14}
# 	[254]: 0.695 (+/-0.031) for {'alpha': 4.0, 'average': False, 'n_iter_no_change': 15}
# 	[255]: 0.695 (+/-0.031) for {'alpha': 4.0, 'average': False, 'n_iter_no_change': 16}
# 	[256]: 0.695 (+/-0.031) for {'alpha': 4.5, 'average': True, 'n_iter_no_change': 1}
# 	[257]: 0.714 (+/-0.078) for {'alpha': 4.5, 'average': True, 'n_iter_no_change': 2}
# 	[258]: 0.714 (+/-0.098) for {'alpha': 4.5, 'average': True, 'n_iter_no_change': 3}
# 	[259]: 0.714 (+/-0.078) for {'alpha': 4.5, 'average': True, 'n_iter_no_change': 4}
# 	[260]: 0.648 (+/-0.215) for {'alpha': 4.5, 'average': True, 'n_iter_no_change': 5}
# 	[261]: 0.686 (+/-0.058) for {'alpha': 4.5, 'average': True, 'n_iter_no_change': 6}
# 	[262]: 0.695 (+/-0.031) for {'alpha': 4.5, 'average': True, 'n_iter_no_change': 7}
# 	[263]: 0.676 (+/-0.153) for {'alpha': 4.5, 'average': True, 'n_iter_no_change': 8}
# 	[264]: 0.705 (+/-0.036) for {'alpha': 4.5, 'average': True, 'n_iter_no_change': 9}
# 	[265]: 0.695 (+/-0.031) for {'alpha': 4.5, 'average': True, 'n_iter_no_change': 10}
# 	[266]: 0.629 (+/-0.260) for {'alpha': 4.5, 'average': True, 'n_iter_no_change': 11}
# 	[267]: 0.695 (+/-0.031) for {'alpha': 4.5, 'average': True, 'n_iter_no_change': 12}
# 	[268]: 0.676 (+/-0.062) for {'alpha': 4.5, 'average': True, 'n_iter_no_change': 13}
# 	[269]: 0.667 (+/-0.070) for {'alpha': 4.5, 'average': True, 'n_iter_no_change': 14}
# 	[270]: 0.657 (+/-0.210) for {'alpha': 4.5, 'average': True, 'n_iter_no_change': 15}
# 	[271]: 0.695 (+/-0.031) for {'alpha': 4.5, 'average': True, 'n_iter_no_change': 16}
# 	[272]: 0.695 (+/-0.031) for {'alpha': 4.5, 'average': False, 'n_iter_no_change': 1}
# 	[273]: 0.695 (+/-0.031) for {'alpha': 4.5, 'average': False, 'n_iter_no_change': 2}
# 	[274]: 0.695 (+/-0.031) for {'alpha': 4.5, 'average': False, 'n_iter_no_change': 3}
# 	[275]: 0.695 (+/-0.031) for {'alpha': 4.5, 'average': False, 'n_iter_no_change': 4}
# 	[276]: 0.695 (+/-0.031) for {'alpha': 4.5, 'average': False, 'n_iter_no_change': 5}
# 	[277]: 0.695 (+/-0.031) for {'alpha': 4.5, 'average': False, 'n_iter_no_change': 6}
# 	[278]: 0.695 (+/-0.031) for {'alpha': 4.5, 'average': False, 'n_iter_no_change': 7}
# 	[279]: 0.695 (+/-0.031) for {'alpha': 4.5, 'average': False, 'n_iter_no_change': 8}
# 	[280]: 0.695 (+/-0.031) for {'alpha': 4.5, 'average': False, 'n_iter_no_change': 9}
# 	[281]: 0.695 (+/-0.031) for {'alpha': 4.5, 'average': False, 'n_iter_no_change': 10}
# 	[282]: 0.695 (+/-0.031) for {'alpha': 4.5, 'average': False, 'n_iter_no_change': 11}
# 	[283]: 0.695 (+/-0.031) for {'alpha': 4.5, 'average': False, 'n_iter_no_change': 12}
# 	[284]: 0.743 (+/-0.194) for {'alpha': 4.5, 'average': False, 'n_iter_no_change': 13}
# 	[285]: 0.695 (+/-0.031) for {'alpha': 4.5, 'average': False, 'n_iter_no_change': 14}
# 	[286]: 0.695 (+/-0.031) for {'alpha': 4.5, 'average': False, 'n_iter_no_change': 15}
# 	[287]: 0.695 (+/-0.031) for {'alpha': 4.5, 'average': False, 'n_iter_no_change': 16}
# 	[288]: 0.695 (+/-0.108) for {'alpha': 5.0, 'average': True, 'n_iter_no_change': 1}
# 	[289]: 0.590 (+/-0.228) for {'alpha': 5.0, 'average': True, 'n_iter_no_change': 2}
# 	[290]: 0.571 (+/-0.159) for {'alpha': 5.0, 'average': True, 'n_iter_no_change': 3}
# 	[291]: 0.648 (+/-0.091) for {'alpha': 5.0, 'average': True, 'n_iter_no_change': 4}
# 	[292]: 0.695 (+/-0.031) for {'alpha': 5.0, 'average': True, 'n_iter_no_change': 5}
# 	[293]: 0.686 (+/-0.058) for {'alpha': 5.0, 'average': True, 'n_iter_no_change': 6}
# 	[294]: 0.619 (+/-0.197) for {'alpha': 5.0, 'average': True, 'n_iter_no_change': 7}
# 	[295]: 0.610 (+/-0.200) for {'alpha': 5.0, 'average': True, 'n_iter_no_change': 8}
# 	[296]: 0.667 (+/-0.229) for {'alpha': 5.0, 'average': True, 'n_iter_no_change': 9}
# 	[297]: 0.686 (+/-0.075) for {'alpha': 5.0, 'average': True, 'n_iter_no_change': 10}
# 	[298]: 0.600 (+/-0.248) for {'alpha': 5.0, 'average': True, 'n_iter_no_change': 11}
# 	[299]: 0.581 (+/-0.256) for {'alpha': 5.0, 'average': True, 'n_iter_no_change': 12}
# 	[300]: 0.629 (+/-0.249) for {'alpha': 5.0, 'average': True, 'n_iter_no_change': 13}
# 	[301]: 0.648 (+/-0.091) for {'alpha': 5.0, 'average': True, 'n_iter_no_change': 14}
# 	[302]: 0.695 (+/-0.031) for {'alpha': 5.0, 'average': True, 'n_iter_no_change': 15}
# 	[303]: 0.686 (+/-0.075) for {'alpha': 5.0, 'average': True, 'n_iter_no_change': 16}
# 	[304]: 0.695 (+/-0.031) for {'alpha': 5.0, 'average': False, 'n_iter_no_change': 1}
# 	[305]: 0.695 (+/-0.031) for {'alpha': 5.0, 'average': False, 'n_iter_no_change': 2}
# 	[306]: 0.695 (+/-0.031) for {'alpha': 5.0, 'average': False, 'n_iter_no_change': 3}
# 	[307]: 0.695 (+/-0.031) for {'alpha': 5.0, 'average': False, 'n_iter_no_change': 4}
# 	[308]: 0.695 (+/-0.031) for {'alpha': 5.0, 'average': False, 'n_iter_no_change': 5}
# 	[309]: 0.695 (+/-0.031) for {'alpha': 5.0, 'average': False, 'n_iter_no_change': 6}
# 	[310]: 0.705 (+/-0.062) for {'alpha': 5.0, 'average': False, 'n_iter_no_change': 7}
# 	[311]: 0.695 (+/-0.031) for {'alpha': 5.0, 'average': False, 'n_iter_no_change': 8}
# 	[312]: 0.695 (+/-0.031) for {'alpha': 5.0, 'average': False, 'n_iter_no_change': 9}
# 	[313]: 0.705 (+/-0.036) for {'alpha': 5.0, 'average': False, 'n_iter_no_change': 10}
# 	[314]: 0.705 (+/-0.062) for {'alpha': 5.0, 'average': False, 'n_iter_no_change': 11}
# 	[315]: 0.705 (+/-0.036) for {'alpha': 5.0, 'average': False, 'n_iter_no_change': 12}
# 	[316]: 0.695 (+/-0.031) for {'alpha': 5.0, 'average': False, 'n_iter_no_change': 13}
# 	[317]: 0.695 (+/-0.031) for {'alpha': 5.0, 'average': False, 'n_iter_no_change': 14}
# 	[318]: 0.705 (+/-0.062) for {'alpha': 5.0, 'average': False, 'n_iter_no_change': 15}
# 	[319]: 0.695 (+/-0.031) for {'alpha': 5.0, 'average': False, 'n_iter_no_change': 16}
# 	[320]: 0.695 (+/-0.031) for {'alpha': 5.5, 'average': True, 'n_iter_no_change': 1}
# 	[321]: 0.724 (+/-0.101) for {'alpha': 5.5, 'average': True, 'n_iter_no_change': 2}
# 	[322]: 0.600 (+/-0.276) for {'alpha': 5.5, 'average': True, 'n_iter_no_change': 3}
# 	[323]: 0.629 (+/-0.205) for {'alpha': 5.5, 'average': True, 'n_iter_no_change': 4}
# 	[324]: 0.571 (+/-0.221) for {'alpha': 5.5, 'average': True, 'n_iter_no_change': 5}
# 	[325]: 0.695 (+/-0.031) for {'alpha': 5.5, 'average': True, 'n_iter_no_change': 6}
# 	[326]: 0.676 (+/-0.062) for {'alpha': 5.5, 'average': True, 'n_iter_no_change': 7}
# 	[327]: 0.695 (+/-0.031) for {'alpha': 5.5, 'average': True, 'n_iter_no_change': 8}
# 	[328]: 0.657 (+/-0.262) for {'alpha': 5.5, 'average': True, 'n_iter_no_change': 9}
# 	[329]: 0.695 (+/-0.031) for {'alpha': 5.5, 'average': True, 'n_iter_no_change': 10}
# 	[330]: 0.714 (+/-0.098) for {'alpha': 5.5, 'average': True, 'n_iter_no_change': 11}
# 	[331]: 0.695 (+/-0.031) for {'alpha': 5.5, 'average': True, 'n_iter_no_change': 12}
# 	[332]: 0.657 (+/-0.230) for {'alpha': 5.5, 'average': True, 'n_iter_no_change': 13}
# 	[333]: 0.667 (+/-0.260) for {'alpha': 5.5, 'average': True, 'n_iter_no_change': 14}
# 	[334]: 0.714 (+/-0.063) for {'alpha': 5.5, 'average': True, 'n_iter_no_change': 15}
# 	[335]: 0.629 (+/-0.274) for {'alpha': 5.5, 'average': True, 'n_iter_no_change': 16}
# 	[336]: 0.695 (+/-0.031) for {'alpha': 5.5, 'average': False, 'n_iter_no_change': 1}
# 	[337]: 0.695 (+/-0.031) for {'alpha': 5.5, 'average': False, 'n_iter_no_change': 2}
# 	[338]: 0.695 (+/-0.031) for {'alpha': 5.5, 'average': False, 'n_iter_no_change': 3}
# 	[339]: 0.686 (+/-0.058) for {'alpha': 5.5, 'average': False, 'n_iter_no_change': 4}
# 	[340]: 0.695 (+/-0.031) for {'alpha': 5.5, 'average': False, 'n_iter_no_change': 5}
# 	[341]: 0.695 (+/-0.031) for {'alpha': 5.5, 'average': False, 'n_iter_no_change': 6}
# 	[342]: 0.695 (+/-0.084) for {'alpha': 5.5, 'average': False, 'n_iter_no_change': 7}
# 	[343]: 0.695 (+/-0.067) for {'alpha': 5.5, 'average': False, 'n_iter_no_change': 8}
# 	[344]: 0.705 (+/-0.062) for {'alpha': 5.5, 'average': False, 'n_iter_no_change': 9}
# 	[345]: 0.695 (+/-0.031) for {'alpha': 5.5, 'average': False, 'n_iter_no_change': 10}
# 	[346]: 0.695 (+/-0.031) for {'alpha': 5.5, 'average': False, 'n_iter_no_change': 11}
# 	[347]: 0.705 (+/-0.036) for {'alpha': 5.5, 'average': False, 'n_iter_no_change': 12}
# 	[348]: 0.695 (+/-0.031) for {'alpha': 5.5, 'average': False, 'n_iter_no_change': 13}
# 	[349]: 0.695 (+/-0.031) for {'alpha': 5.5, 'average': False, 'n_iter_no_change': 14}
# 	[350]: 0.695 (+/-0.031) for {'alpha': 5.5, 'average': False, 'n_iter_no_change': 15}
# 	[351]: 0.686 (+/-0.058) for {'alpha': 5.5, 'average': False, 'n_iter_no_change': 16}
# 	[352]: 0.486 (+/-0.250) for {'alpha': 6.0, 'average': True, 'n_iter_no_change': 1}
# 	[353]: 0.581 (+/-0.272) for {'alpha': 6.0, 'average': True, 'n_iter_no_change': 2}
# 	[354]: 0.581 (+/-0.308) for {'alpha': 6.0, 'average': True, 'n_iter_no_change': 3}
# 	[355]: 0.638 (+/-0.178) for {'alpha': 6.0, 'average': True, 'n_iter_no_change': 4}
# 	[356]: 0.695 (+/-0.031) for {'alpha': 6.0, 'average': True, 'n_iter_no_change': 5}
# 	[357]: 0.724 (+/-0.105) for {'alpha': 6.0, 'average': True, 'n_iter_no_change': 6}
# 	[358]: 0.657 (+/-0.136) for {'alpha': 6.0, 'average': True, 'n_iter_no_change': 7}
# 	[359]: 0.581 (+/-0.299) for {'alpha': 6.0, 'average': True, 'n_iter_no_change': 8}
# 	[360]: 0.695 (+/-0.031) for {'alpha': 6.0, 'average': True, 'n_iter_no_change': 9}
# 	[361]: 0.695 (+/-0.031) for {'alpha': 6.0, 'average': True, 'n_iter_no_change': 10}
# 	[362]: 0.657 (+/-0.184) for {'alpha': 6.0, 'average': True, 'n_iter_no_change': 11}
# 	[363]: 0.533 (+/-0.274) for {'alpha': 6.0, 'average': True, 'n_iter_no_change': 12}
# 	[364]: 0.695 (+/-0.031) for {'alpha': 6.0, 'average': True, 'n_iter_no_change': 13}
# 	[365]: 0.705 (+/-0.098) for {'alpha': 6.0, 'average': True, 'n_iter_no_change': 14}
# 	[366]: 0.581 (+/-0.315) for {'alpha': 6.0, 'average': True, 'n_iter_no_change': 15}
# 	[367]: 0.667 (+/-0.128) for {'alpha': 6.0, 'average': True, 'n_iter_no_change': 16}
# 	[368]: 0.695 (+/-0.031) for {'alpha': 6.0, 'average': False, 'n_iter_no_change': 1}
# 	[369]: 0.705 (+/-0.036) for {'alpha': 6.0, 'average': False, 'n_iter_no_change': 2}
# 	[370]: 0.695 (+/-0.031) for {'alpha': 6.0, 'average': False, 'n_iter_no_change': 3}
# 	[371]: 0.695 (+/-0.031) for {'alpha': 6.0, 'average': False, 'n_iter_no_change': 4}
# 	[372]: 0.695 (+/-0.031) for {'alpha': 6.0, 'average': False, 'n_iter_no_change': 5}
# 	[373]: 0.695 (+/-0.031) for {'alpha': 6.0, 'average': False, 'n_iter_no_change': 6}
# 	[374]: 0.695 (+/-0.031) for {'alpha': 6.0, 'average': False, 'n_iter_no_change': 7}
# 	[375]: 0.695 (+/-0.031) for {'alpha': 6.0, 'average': False, 'n_iter_no_change': 8}
# 	[376]: 0.695 (+/-0.031) for {'alpha': 6.0, 'average': False, 'n_iter_no_change': 9}
# 	[377]: 0.705 (+/-0.036) for {'alpha': 6.0, 'average': False, 'n_iter_no_change': 10}
# 	[378]: 0.705 (+/-0.036) for {'alpha': 6.0, 'average': False, 'n_iter_no_change': 11}
# 	[379]: 0.686 (+/-0.058) for {'alpha': 6.0, 'average': False, 'n_iter_no_change': 12}
# 	[380]: 0.705 (+/-0.036) for {'alpha': 6.0, 'average': False, 'n_iter_no_change': 13}
# 	[381]: 0.705 (+/-0.036) for {'alpha': 6.0, 'average': False, 'n_iter_no_change': 14}
# 	[382]: 0.695 (+/-0.031) for {'alpha': 6.0, 'average': False, 'n_iter_no_change': 15}
# 	[383]: 0.705 (+/-0.062) for {'alpha': 6.0, 'average': False, 'n_iter_no_change': 16}
# 	[384]: 0.571 (+/-0.316) for {'alpha': 6.5, 'average': True, 'n_iter_no_change': 1}
# 	[385]: 0.619 (+/-0.269) for {'alpha': 6.5, 'average': True, 'n_iter_no_change': 2}
# 	[386]: 0.695 (+/-0.031) for {'alpha': 6.5, 'average': True, 'n_iter_no_change': 3}
# 	[387]: 0.638 (+/-0.255) for {'alpha': 6.5, 'average': True, 'n_iter_no_change': 4}
# 	[388]: 0.524 (+/-0.278) for {'alpha': 6.5, 'average': True, 'n_iter_no_change': 5}
# 	[389]: 0.648 (+/-0.297) for {'alpha': 6.5, 'average': True, 'n_iter_no_change': 6}
# 	[390]: 0.676 (+/-0.051) for {'alpha': 6.5, 'average': True, 'n_iter_no_change': 7}
# 	[391]: 0.695 (+/-0.031) for {'alpha': 6.5, 'average': True, 'n_iter_no_change': 8}
# 	[392]: 0.695 (+/-0.031) for {'alpha': 6.5, 'average': True, 'n_iter_no_change': 9}
# 	[393]: 0.657 (+/-0.262) for {'alpha': 6.5, 'average': True, 'n_iter_no_change': 10}
# 	[394]: 0.657 (+/-0.092) for {'alpha': 6.5, 'average': True, 'n_iter_no_change': 11}
# 	[395]: 0.543 (+/-0.262) for {'alpha': 6.5, 'average': True, 'n_iter_no_change': 12}
# 	[396]: 0.505 (+/-0.286) for {'alpha': 6.5, 'average': True, 'n_iter_no_change': 13}
# 	[397]: 0.619 (+/-0.243) for {'alpha': 6.5, 'average': True, 'n_iter_no_change': 14}
# 	[398]: 0.571 (+/-0.330) for {'alpha': 6.5, 'average': True, 'n_iter_no_change': 15}
# 	[399]: 0.600 (+/-0.262) for {'alpha': 6.5, 'average': True, 'n_iter_no_change': 16}
# 	[400]: 0.695 (+/-0.031) for {'alpha': 6.5, 'average': False, 'n_iter_no_change': 1}
# 	[401]: 0.695 (+/-0.031) for {'alpha': 6.5, 'average': False, 'n_iter_no_change': 2}
# 	[402]: 0.686 (+/-0.058) for {'alpha': 6.5, 'average': False, 'n_iter_no_change': 3}
# 	[403]: 0.695 (+/-0.031) for {'alpha': 6.5, 'average': False, 'n_iter_no_change': 4}
# 	[404]: 0.695 (+/-0.031) for {'alpha': 6.5, 'average': False, 'n_iter_no_change': 5}
# 	[405]: 0.695 (+/-0.031) for {'alpha': 6.5, 'average': False, 'n_iter_no_change': 6}
# 	[406]: 0.676 (+/-0.146) for {'alpha': 6.5, 'average': False, 'n_iter_no_change': 7}
# 	[407]: 0.695 (+/-0.031) for {'alpha': 6.5, 'average': False, 'n_iter_no_change': 8}
# 	[408]: 0.695 (+/-0.031) for {'alpha': 6.5, 'average': False, 'n_iter_no_change': 9}
# 	[409]: 0.667 (+/-0.101) for {'alpha': 6.5, 'average': False, 'n_iter_no_change': 10}
# 	[410]: 0.695 (+/-0.031) for {'alpha': 6.5, 'average': False, 'n_iter_no_change': 11}
# 	[411]: 0.705 (+/-0.036) for {'alpha': 6.5, 'average': False, 'n_iter_no_change': 12}
# 	[412]: 0.686 (+/-0.058) for {'alpha': 6.5, 'average': False, 'n_iter_no_change': 13}
# 	[413]: 0.695 (+/-0.084) for {'alpha': 6.5, 'average': False, 'n_iter_no_change': 14}
# 	[414]: 0.657 (+/-0.164) for {'alpha': 6.5, 'average': False, 'n_iter_no_change': 15}
# 	[415]: 0.667 (+/-0.069) for {'alpha': 6.5, 'average': False, 'n_iter_no_change': 16}
# 	[416]: 0.495 (+/-0.322) for {'alpha': 7.0, 'average': True, 'n_iter_no_change': 1}
# 	[417]: 0.657 (+/-0.317) for {'alpha': 7.0, 'average': True, 'n_iter_no_change': 2}
# 	[418]: 0.581 (+/-0.272) for {'alpha': 7.0, 'average': True, 'n_iter_no_change': 3}
# 	[419]: 0.705 (+/-0.117) for {'alpha': 7.0, 'average': True, 'n_iter_no_change': 4}
# 	[420]: 0.600 (+/-0.262) for {'alpha': 7.0, 'average': True, 'n_iter_no_change': 5}
# 	[421]: 0.657 (+/-0.136) for {'alpha': 7.0, 'average': True, 'n_iter_no_change': 6}
# 	[422]: 0.629 (+/-0.176) for {'alpha': 7.0, 'average': True, 'n_iter_no_change': 7}
# 	[423]: 0.571 (+/-0.316) for {'alpha': 7.0, 'average': True, 'n_iter_no_change': 8}
# 	[424]: 0.676 (+/-0.096) for {'alpha': 7.0, 'average': True, 'n_iter_no_change': 9}
# 	[425]: 0.571 (+/-0.281) for {'alpha': 7.0, 'average': True, 'n_iter_no_change': 10}
# 	[426]: 0.657 (+/-0.278) for {'alpha': 7.0, 'average': True, 'n_iter_no_change': 11}
# 	[427]: 0.638 (+/-0.211) for {'alpha': 7.0, 'average': True, 'n_iter_no_change': 12}
# 	[428]: 0.629 (+/-0.274) for {'alpha': 7.0, 'average': True, 'n_iter_no_change': 13}
# 	[429]: 0.600 (+/-0.263) for {'alpha': 7.0, 'average': True, 'n_iter_no_change': 14}
# 	[430]: 0.552 (+/-0.305) for {'alpha': 7.0, 'average': True, 'n_iter_no_change': 15}
# 	[431]: 0.543 (+/-0.288) for {'alpha': 7.0, 'average': True, 'n_iter_no_change': 16}
# 	[432]: 0.724 (+/-0.101) for {'alpha': 7.0, 'average': False, 'n_iter_no_change': 1}
# 	[433]: 0.629 (+/-0.140) for {'alpha': 7.0, 'average': False, 'n_iter_no_change': 2}
# 	[434]: 0.695 (+/-0.031) for {'alpha': 7.0, 'average': False, 'n_iter_no_change': 3}
# 	[435]: 0.648 (+/-0.155) for {'alpha': 7.0, 'average': False, 'n_iter_no_change': 4}
# 	[436]: 0.705 (+/-0.062) for {'alpha': 7.0, 'average': False, 'n_iter_no_change': 5}
# 	[437]: 0.686 (+/-0.058) for {'alpha': 7.0, 'average': False, 'n_iter_no_change': 6}
# 	[438]: 0.676 (+/-0.092) for {'alpha': 7.0, 'average': False, 'n_iter_no_change': 7}
# 	[439]: 0.648 (+/-0.185) for {'alpha': 7.0, 'average': False, 'n_iter_no_change': 8}
# 	[440]: 0.724 (+/-0.076) for {'alpha': 7.0, 'average': False, 'n_iter_no_change': 9}
# 	[441]: 0.657 (+/-0.164) for {'alpha': 7.0, 'average': False, 'n_iter_no_change': 10}
# 	[442]: 0.676 (+/-0.062) for {'alpha': 7.0, 'average': False, 'n_iter_no_change': 11}
# 	[443]: 0.724 (+/-0.127) for {'alpha': 7.0, 'average': False, 'n_iter_no_change': 12}
# 	[444]: 0.695 (+/-0.084) for {'alpha': 7.0, 'average': False, 'n_iter_no_change': 13}
# 	[445]: 0.695 (+/-0.084) for {'alpha': 7.0, 'average': False, 'n_iter_no_change': 14}
# 	[446]: 0.714 (+/-0.245) for {'alpha': 7.0, 'average': False, 'n_iter_no_change': 15}
# 	[447]: 0.695 (+/-0.067) for {'alpha': 7.0, 'average': False, 'n_iter_no_change': 16}
# 	[448]: 0.714 (+/-0.066) for {'alpha': 7.5, 'average': True, 'n_iter_no_change': 1}
# 	[449]: 0.695 (+/-0.031) for {'alpha': 7.5, 'average': True, 'n_iter_no_change': 2}
# 	[450]: 0.590 (+/-0.385) for {'alpha': 7.5, 'average': True, 'n_iter_no_change': 3}
# 	[451]: 0.629 (+/-0.249) for {'alpha': 7.5, 'average': True, 'n_iter_no_change': 4}
# 	[452]: 0.571 (+/-0.270) for {'alpha': 7.5, 'average': True, 'n_iter_no_change': 5}
# 	[453]: 0.590 (+/-0.251) for {'alpha': 7.5, 'average': True, 'n_iter_no_change': 6}
# 	[454]: 0.590 (+/-0.234) for {'alpha': 7.5, 'average': True, 'n_iter_no_change': 7}
# 	[455]: 0.676 (+/-0.062) for {'alpha': 7.5, 'average': True, 'n_iter_no_change': 8}
# 	[456]: 0.571 (+/-0.309) for {'alpha': 7.5, 'average': True, 'n_iter_no_change': 9}
# 	[457]: 0.533 (+/-0.272) for {'alpha': 7.5, 'average': True, 'n_iter_no_change': 10}
# 	[458]: 0.629 (+/-0.233) for {'alpha': 7.5, 'average': True, 'n_iter_no_change': 11}
# 	[459]: 0.686 (+/-0.172) for {'alpha': 7.5, 'average': True, 'n_iter_no_change': 12}
# 	[460]: 0.562 (+/-0.337) for {'alpha': 7.5, 'average': True, 'n_iter_no_change': 13}
# 	[461]: 0.505 (+/-0.322) for {'alpha': 7.5, 'average': True, 'n_iter_no_change': 14}
# 	[462]: 0.514 (+/-0.378) for {'alpha': 7.5, 'average': True, 'n_iter_no_change': 15}
# 	[463]: 0.562 (+/-0.295) for {'alpha': 7.5, 'average': True, 'n_iter_no_change': 16}
# 	[464]: 0.590 (+/-0.272) for {'alpha': 7.5, 'average': False, 'n_iter_no_change': 1}
# 	[465]: 0.695 (+/-0.031) for {'alpha': 7.5, 'average': False, 'n_iter_no_change': 2}
# 	[466]: 0.619 (+/-0.274) for {'alpha': 7.5, 'average': False, 'n_iter_no_change': 3}
# 	[467]: 0.648 (+/-0.166) for {'alpha': 7.5, 'average': False, 'n_iter_no_change': 4}
# 	[468]: 0.686 (+/-0.031) for {'alpha': 7.5, 'average': False, 'n_iter_no_change': 5}
# 	[469]: 0.648 (+/-0.201) for {'alpha': 7.5, 'average': False, 'n_iter_no_change': 6}
# 	[470]: 0.695 (+/-0.031) for {'alpha': 7.5, 'average': False, 'n_iter_no_change': 7}
# 	[471]: 0.705 (+/-0.042) for {'alpha': 7.5, 'average': False, 'n_iter_no_change': 8}
# 	[472]: 0.657 (+/-0.136) for {'alpha': 7.5, 'average': False, 'n_iter_no_change': 9}
# 	[473]: 0.695 (+/-0.031) for {'alpha': 7.5, 'average': False, 'n_iter_no_change': 10}
# 	[474]: 0.705 (+/-0.042) for {'alpha': 7.5, 'average': False, 'n_iter_no_change': 11}
# 	[475]: 0.705 (+/-0.036) for {'alpha': 7.5, 'average': False, 'n_iter_no_change': 12}
# 	[476]: 0.562 (+/-0.248) for {'alpha': 7.5, 'average': False, 'n_iter_no_change': 13}
# 	[477]: 0.657 (+/-0.220) for {'alpha': 7.5, 'average': False, 'n_iter_no_change': 14}
# 	[478]: 0.676 (+/-0.062) for {'alpha': 7.5, 'average': False, 'n_iter_no_change': 15}
# 	[479]: 0.619 (+/-0.135) for {'alpha': 7.5, 'average': False, 'n_iter_no_change': 16}
# 	[480]: 0.676 (+/-0.092) for {'alpha': 8.0, 'average': True, 'n_iter_no_change': 1}
# 	[481]: 0.600 (+/-0.414) for {'alpha': 8.0, 'average': True, 'n_iter_no_change': 2}
# 	[482]: 0.695 (+/-0.031) for {'alpha': 8.0, 'average': True, 'n_iter_no_change': 3}
# 	[483]: 0.495 (+/-0.322) for {'alpha': 8.0, 'average': True, 'n_iter_no_change': 4}
# 	[484]: 0.629 (+/-0.274) for {'alpha': 8.0, 'average': True, 'n_iter_no_change': 5}
# 	[485]: 0.505 (+/-0.322) for {'alpha': 8.0, 'average': True, 'n_iter_no_change': 6}
# 	[486]: 0.676 (+/-0.146) for {'alpha': 8.0, 'average': True, 'n_iter_no_change': 7}
# 	[487]: 0.600 (+/-0.248) for {'alpha': 8.0, 'average': True, 'n_iter_no_change': 8}
# 	[488]: 0.657 (+/-0.216) for {'alpha': 8.0, 'average': True, 'n_iter_no_change': 9}
# 	[489]: 0.648 (+/-0.373) for {'alpha': 8.0, 'average': True, 'n_iter_no_change': 10}
# 	[490]: 0.552 (+/-0.312) for {'alpha': 8.0, 'average': True, 'n_iter_no_change': 11}
# 	[491]: 0.610 (+/-0.261) for {'alpha': 8.0, 'average': True, 'n_iter_no_change': 12}
# 	[492]: 0.619 (+/-0.244) for {'alpha': 8.0, 'average': True, 'n_iter_no_change': 13}
# 	[493]: 0.657 (+/-0.316) for {'alpha': 8.0, 'average': True, 'n_iter_no_change': 14}
# 	[494]: 0.590 (+/-0.260) for {'alpha': 8.0, 'average': True, 'n_iter_no_change': 15}
# 	[495]: 0.629 (+/-0.249) for {'alpha': 8.0, 'average': True, 'n_iter_no_change': 16}
# 	[496]: 0.667 (+/-0.098) for {'alpha': 8.0, 'average': False, 'n_iter_no_change': 1}
# 	[497]: 0.657 (+/-0.282) for {'alpha': 8.0, 'average': False, 'n_iter_no_change': 2}
# 	[498]: 0.695 (+/-0.031) for {'alpha': 8.0, 'average': False, 'n_iter_no_change': 3}
# 	[499]: 0.667 (+/-0.249) for {'alpha': 8.0, 'average': False, 'n_iter_no_change': 4}
# 	[500]: 0.562 (+/-0.248) for {'alpha': 8.0, 'average': False, 'n_iter_no_change': 5}
# 	[501]: 0.638 (+/-0.255) for {'alpha': 8.0, 'average': False, 'n_iter_no_change': 6}
# 	[502]: 0.638 (+/-0.237) for {'alpha': 8.0, 'average': False, 'n_iter_no_change': 7}
# 	[503]: 0.695 (+/-0.031) for {'alpha': 8.0, 'average': False, 'n_iter_no_change': 8}
# 	[504]: 0.581 (+/-0.206) for {'alpha': 8.0, 'average': False, 'n_iter_no_change': 9}
# 	[505]: 0.695 (+/-0.031) for {'alpha': 8.0, 'average': False, 'n_iter_no_change': 10}
# 	[506]: 0.629 (+/-0.274) for {'alpha': 8.0, 'average': False, 'n_iter_no_change': 11}
# 	[507]: 0.629 (+/-0.136) for {'alpha': 8.0, 'average': False, 'n_iter_no_change': 12}
# 	[508]: 0.695 (+/-0.031) for {'alpha': 8.0, 'average': False, 'n_iter_no_change': 13}
# 	[509]: 0.581 (+/-0.307) for {'alpha': 8.0, 'average': False, 'n_iter_no_change': 14}
# 	[510]: 0.743 (+/-0.155) for {'alpha': 8.0, 'average': False, 'n_iter_no_change': 15}
# 	[511]: 0.695 (+/-0.031) for {'alpha': 8.0, 'average': False, 'n_iter_no_change': 16}
# 	[512]: 0.686 (+/-0.058) for {'alpha': 8.5, 'average': True, 'n_iter_no_change': 1}
# 	[513]: 0.562 (+/-0.334) for {'alpha': 8.5, 'average': True, 'n_iter_no_change': 2}
# 	[514]: 0.610 (+/-0.258) for {'alpha': 8.5, 'average': True, 'n_iter_no_change': 3}
# 	[515]: 0.638 (+/-0.255) for {'alpha': 8.5, 'average': True, 'n_iter_no_change': 4}
# 	[516]: 0.533 (+/-0.269) for {'alpha': 8.5, 'average': True, 'n_iter_no_change': 5}
# 	[517]: 0.648 (+/-0.122) for {'alpha': 8.5, 'average': True, 'n_iter_no_change': 6}
# 	[518]: 0.562 (+/-0.317) for {'alpha': 8.5, 'average': True, 'n_iter_no_change': 7}
# 	[519]: 0.571 (+/-0.356) for {'alpha': 8.5, 'average': True, 'n_iter_no_change': 8}
# 	[520]: 0.676 (+/-0.071) for {'alpha': 8.5, 'average': True, 'n_iter_no_change': 9}
# 	[521]: 0.705 (+/-0.042) for {'alpha': 8.5, 'average': True, 'n_iter_no_change': 10}
# 	[522]: 0.600 (+/-0.253) for {'alpha': 8.5, 'average': True, 'n_iter_no_change': 11}
# 	[523]: 0.514 (+/-0.250) for {'alpha': 8.5, 'average': True, 'n_iter_no_change': 12}
# 	[524]: 0.524 (+/-0.293) for {'alpha': 8.5, 'average': True, 'n_iter_no_change': 13}
# 	[525]: 0.600 (+/-0.284) for {'alpha': 8.5, 'average': True, 'n_iter_no_change': 14}
# 	[526]: 0.590 (+/-0.261) for {'alpha': 8.5, 'average': True, 'n_iter_no_change': 15}
# 	[527]: 0.629 (+/-0.274) for {'alpha': 8.5, 'average': True, 'n_iter_no_change': 16}
# 	[528]: 0.562 (+/-0.317) for {'alpha': 8.5, 'average': False, 'n_iter_no_change': 1}
# 	[529]: 0.629 (+/-0.249) for {'alpha': 8.5, 'average': False, 'n_iter_no_change': 2}
# 	[530]: 0.610 (+/-0.309) for {'alpha': 8.5, 'average': False, 'n_iter_no_change': 3}
# 	[531]: 0.590 (+/-0.362) for {'alpha': 8.5, 'average': False, 'n_iter_no_change': 4}
# 	[532]: 0.638 (+/-0.260) for {'alpha': 8.5, 'average': False, 'n_iter_no_change': 5}
# 	[533]: 0.638 (+/-0.211) for {'alpha': 8.5, 'average': False, 'n_iter_no_change': 6}
# 	[534]: 0.648 (+/-0.215) for {'alpha': 8.5, 'average': False, 'n_iter_no_change': 7}
# 	[535]: 0.571 (+/-0.316) for {'alpha': 8.5, 'average': False, 'n_iter_no_change': 8}
# 	[536]: 0.638 (+/-0.255) for {'alpha': 8.5, 'average': False, 'n_iter_no_change': 9}
# 	[537]: 0.571 (+/-0.274) for {'alpha': 8.5, 'average': False, 'n_iter_no_change': 10}
# 	[538]: 0.695 (+/-0.031) for {'alpha': 8.5, 'average': False, 'n_iter_no_change': 11}
# 	[539]: 0.657 (+/-0.287) for {'alpha': 8.5, 'average': False, 'n_iter_no_change': 12}
# 	[540]: 0.695 (+/-0.031) for {'alpha': 8.5, 'average': False, 'n_iter_no_change': 13}
# 	[541]: 0.657 (+/-0.136) for {'alpha': 8.5, 'average': False, 'n_iter_no_change': 14}
# 	[542]: 0.724 (+/-0.136) for {'alpha': 8.5, 'average': False, 'n_iter_no_change': 15}
# 	[543]: 0.581 (+/-0.281) for {'alpha': 8.5, 'average': False, 'n_iter_no_change': 16}
# 	[544]: 0.610 (+/-0.236) for {'alpha': 9.0, 'average': True, 'n_iter_no_change': 1}
# 	[545]: 0.638 (+/-0.255) for {'alpha': 9.0, 'average': True, 'n_iter_no_change': 2}
# 	[546]: 0.552 (+/-0.301) for {'alpha': 9.0, 'average': True, 'n_iter_no_change': 3}
# 	[547]: 0.590 (+/-0.284) for {'alpha': 9.0, 'average': True, 'n_iter_no_change': 4}
# 	[548]: 0.562 (+/-0.317) for {'alpha': 9.0, 'average': True, 'n_iter_no_change': 5}
# 	[549]: 0.724 (+/-0.101) for {'alpha': 9.0, 'average': True, 'n_iter_no_change': 6}
# 	[550]: 0.610 (+/-0.261) for {'alpha': 9.0, 'average': True, 'n_iter_no_change': 7}
# 	[551]: 0.648 (+/-0.047) for {'alpha': 9.0, 'average': True, 'n_iter_no_change': 8}
# 	[552]: 0.543 (+/-0.328) for {'alpha': 9.0, 'average': True, 'n_iter_no_change': 9}
# 	[553]: 0.695 (+/-0.031) for {'alpha': 9.0, 'average': True, 'n_iter_no_change': 10}
# 	[554]: 0.562 (+/-0.295) for {'alpha': 9.0, 'average': True, 'n_iter_no_change': 11}
# 	[555]: 0.667 (+/-0.135) for {'alpha': 9.0, 'average': True, 'n_iter_no_change': 12}
# 	[556]: 0.667 (+/-0.353) for {'alpha': 9.0, 'average': True, 'n_iter_no_change': 13}
# 	[557]: 0.514 (+/-0.252) for {'alpha': 9.0, 'average': True, 'n_iter_no_change': 14}
# ...
# 	[890]: 0.495 (+/-0.303) for {'alpha': 14.0, 'average': False, 'n_iter_no_change': 11}
# 	[891]: 0.533 (+/-0.202) for {'alpha': 14.0, 'average': False, 'n_iter_no_change': 12}
# 	[892]: 0.533 (+/-0.312) for {'alpha': 14.0, 'average': False, 'n_iter_no_change': 13}
# 	[893]: 0.610 (+/-0.243) for {'alpha': 14.0, 'average': False, 'n_iter_no_change': 14}
# 	[894]: 0.571 (+/-0.309) for {'alpha': 14.0, 'average': False, 'n_iter_no_change': 15}
# 	[895]: 0.486 (+/-0.279) for {'alpha': 14.0, 'average': False, 'n_iter_no_change': 16}
# 	[896]: 0.486 (+/-0.339) for {'alpha': 14.5, 'average': True, 'n_iter_no_change': 1}
# 	[897]: 0.562 (+/-0.317) for {'alpha': 14.5, 'average': True, 'n_iter_no_change': 2}
# 	[898]: 0.733 (+/-0.101) for {'alpha': 14.5, 'average': True, 'n_iter_no_change': 3}
# 	[899]: 0.590 (+/-0.222) for {'alpha': 14.5, 'average': True, 'n_iter_no_change': 4}
# 	[900]: 0.438 (+/-0.251) for {'alpha': 14.5, 'average': True, 'n_iter_no_change': 5}
# 	[901]: 0.524 (+/-0.301) for {'alpha': 14.5, 'average': True, 'n_iter_no_change': 6}
# 	[902]: 0.476 (+/-0.276) for {'alpha': 14.5, 'average': True, 'n_iter_no_change': 7}
# 	[903]: 0.543 (+/-0.347) for {'alpha': 14.5, 'average': True, 'n_iter_no_change': 8}
# 	[904]: 0.657 (+/-0.212) for {'alpha': 14.5, 'average': True, 'n_iter_no_change': 9}
# 	[905]: 0.419 (+/-0.104) for {'alpha': 14.5, 'average': True, 'n_iter_no_change': 10}
# 	[906]: 0.495 (+/-0.266) for {'alpha': 14.5, 'average': True, 'n_iter_no_change': 11}
# 	[907]: 0.486 (+/-0.279) for {'alpha': 14.5, 'average': True, 'n_iter_no_change': 12}
# 	[908]: 0.514 (+/-0.273) for {'alpha': 14.5, 'average': True, 'n_iter_no_change': 13}
# 	[909]: 0.533 (+/-0.281) for {'alpha': 14.5, 'average': True, 'n_iter_no_change': 14}
# 	[910]: 0.429 (+/-0.240) for {'alpha': 14.5, 'average': True, 'n_iter_no_change': 15}
# 	[911]: 0.495 (+/-0.299) for {'alpha': 14.5, 'average': True, 'n_iter_no_change': 16}
# 	[912]: 0.571 (+/-0.330) for {'alpha': 14.5, 'average': False, 'n_iter_no_change': 1}
# 	[913]: 0.590 (+/-0.266) for {'alpha': 14.5, 'average': False, 'n_iter_no_change': 2}
# 	[914]: 0.438 (+/-0.251) for {'alpha': 14.5, 'average': False, 'n_iter_no_change': 3}
# 	[915]: 0.533 (+/-0.281) for {'alpha': 14.5, 'average': False, 'n_iter_no_change': 4}
# 	[916]: 0.590 (+/-0.269) for {'alpha': 14.5, 'average': False, 'n_iter_no_change': 5}
# 	[917]: 0.571 (+/-0.309) for {'alpha': 14.5, 'average': False, 'n_iter_no_change': 6}
# 	[918]: 0.505 (+/-0.342) for {'alpha': 14.5, 'average': False, 'n_iter_no_change': 7}
# 	[919]: 0.505 (+/-0.322) for {'alpha': 14.5, 'average': False, 'n_iter_no_change': 8}
# 	[920]: 0.533 (+/-0.312) for {'alpha': 14.5, 'average': False, 'n_iter_no_change': 9}
# 	[921]: 0.571 (+/-0.234) for {'alpha': 14.5, 'average': False, 'n_iter_no_change': 10}
# 	[922]: 0.371 (+/-0.016) for {'alpha': 14.5, 'average': False, 'n_iter_no_change': 11}
# 	[923]: 0.590 (+/-0.248) for {'alpha': 14.5, 'average': False, 'n_iter_no_change': 12}
# 	[924]: 0.495 (+/-0.322) for {'alpha': 14.5, 'average': False, 'n_iter_no_change': 13}
# 	[925]: 0.610 (+/-0.246) for {'alpha': 14.5, 'average': False, 'n_iter_no_change': 14}
# 	[926]: 0.486 (+/-0.302) for {'alpha': 14.5, 'average': False, 'n_iter_no_change': 15}
# 	[927]: 0.562 (+/-0.317) for {'alpha': 14.5, 'average': False, 'n_iter_no_change': 16}
# 	[928]: 0.505 (+/-0.232) for {'alpha': 15.0, 'average': True, 'n_iter_no_change': 1}
# 	[929]: 0.438 (+/-0.251) for {'alpha': 15.0, 'average': True, 'n_iter_no_change': 2}
# 	[930]: 0.438 (+/-0.251) for {'alpha': 15.0, 'average': True, 'n_iter_no_change': 3}
# 	[931]: 0.448 (+/-0.200) for {'alpha': 15.0, 'average': True, 'n_iter_no_change': 4}
# 	[932]: 0.552 (+/-0.305) for {'alpha': 15.0, 'average': True, 'n_iter_no_change': 5}
# 	[933]: 0.457 (+/-0.245) for {'alpha': 15.0, 'average': True, 'n_iter_no_change': 6}
# 	[934]: 0.419 (+/-0.200) for {'alpha': 15.0, 'average': True, 'n_iter_no_change': 7}
# 	[935]: 0.505 (+/-0.322) for {'alpha': 15.0, 'average': True, 'n_iter_no_change': 8}
# 	[936]: 0.438 (+/-0.251) for {'alpha': 15.0, 'average': True, 'n_iter_no_change': 9}
# 	[937]: 0.429 (+/-0.238) for {'alpha': 15.0, 'average': True, 'n_iter_no_change': 10}
# 	[938]: 0.552 (+/-0.232) for {'alpha': 15.0, 'average': True, 'n_iter_no_change': 11}
# 	[939]: 0.514 (+/-0.431) for {'alpha': 15.0, 'average': True, 'n_iter_no_change': 12}
# 	[940]: 0.552 (+/-0.305) for {'alpha': 15.0, 'average': True, 'n_iter_no_change': 13}
# 	[941]: 0.638 (+/-0.255) for {'alpha': 15.0, 'average': True, 'n_iter_no_change': 14}
# 	[942]: 0.562 (+/-0.315) for {'alpha': 15.0, 'average': True, 'n_iter_no_change': 15}
# 	[943]: 0.562 (+/-0.147) for {'alpha': 15.0, 'average': True, 'n_iter_no_change': 16}
# 	[944]: 0.524 (+/-0.325) for {'alpha': 15.0, 'average': False, 'n_iter_no_change': 1}
# 	[945]: 0.552 (+/-0.305) for {'alpha': 15.0, 'average': False, 'n_iter_no_change': 2}
# 	[946]: 0.571 (+/-0.309) for {'alpha': 15.0, 'average': False, 'n_iter_no_change': 3}
# 	[947]: 0.619 (+/-0.243) for {'alpha': 15.0, 'average': False, 'n_iter_no_change': 4}
# 	[948]: 0.571 (+/-0.330) for {'alpha': 15.0, 'average': False, 'n_iter_no_change': 5}
# 	[949]: 0.552 (+/-0.282) for {'alpha': 15.0, 'average': False, 'n_iter_no_change': 6}
# 	[950]: 0.581 (+/-0.238) for {'alpha': 15.0, 'average': False, 'n_iter_no_change': 7}
# 	[951]: 0.629 (+/-0.286) for {'alpha': 15.0, 'average': False, 'n_iter_no_change': 8}
# 	[952]: 0.476 (+/-0.276) for {'alpha': 15.0, 'average': False, 'n_iter_no_change': 9}
# 	[953]: 0.467 (+/-0.290) for {'alpha': 15.0, 'average': False, 'n_iter_no_change': 10}
# 	[954]: 0.686 (+/-0.059) for {'alpha': 15.0, 'average': False, 'n_iter_no_change': 11}
# 	[955]: 0.514 (+/-0.249) for {'alpha': 15.0, 'average': False, 'n_iter_no_change': 12}
# 	[956]: 0.438 (+/-0.276) for {'alpha': 15.0, 'average': False, 'n_iter_no_change': 13}
# 	[957]: 0.657 (+/-0.287) for {'alpha': 15.0, 'average': False, 'n_iter_no_change': 14}
# 	[958]: 0.543 (+/-0.291) for {'alpha': 15.0, 'average': False, 'n_iter_no_change': 15}
# 	[959]: 0.552 (+/-0.305) for {'alpha': 15.0, 'average': False, 'n_iter_no_change': 16}
# 	[960]: 0.562 (+/-0.319) for {'alpha': 15.5, 'average': True, 'n_iter_no_change': 1}
# 	[961]: 0.505 (+/-0.275) for {'alpha': 15.5, 'average': True, 'n_iter_no_change': 2}
# 	[962]: 0.571 (+/-0.330) for {'alpha': 15.5, 'average': True, 'n_iter_no_change': 3}
# 	[963]: 0.429 (+/-0.241) for {'alpha': 15.5, 'average': True, 'n_iter_no_change': 4}
# 	[964]: 0.438 (+/-0.193) for {'alpha': 15.5, 'average': True, 'n_iter_no_change': 5}
# 	[965]: 0.600 (+/-0.249) for {'alpha': 15.5, 'average': True, 'n_iter_no_change': 6}
# 	[966]: 0.514 (+/-0.321) for {'alpha': 15.5, 'average': True, 'n_iter_no_change': 7}
# 	[967]: 0.600 (+/-0.248) for {'alpha': 15.5, 'average': True, 'n_iter_no_change': 8}
# 	[968]: 0.590 (+/-0.296) for {'alpha': 15.5, 'average': True, 'n_iter_no_change': 9}
# 	[969]: 0.581 (+/-0.308) for {'alpha': 15.5, 'average': True, 'n_iter_no_change': 10}
# 	[970]: 0.590 (+/-0.284) for {'alpha': 15.5, 'average': True, 'n_iter_no_change': 11}
# 	[971]: 0.486 (+/-0.302) for {'alpha': 15.5, 'average': True, 'n_iter_no_change': 12}
# 	[972]: 0.562 (+/-0.298) for {'alpha': 15.5, 'average': True, 'n_iter_no_change': 13}
# 	[973]: 0.533 (+/-0.334) for {'alpha': 15.5, 'average': True, 'n_iter_no_change': 14}
# 	[974]: 0.562 (+/-0.319) for {'alpha': 15.5, 'average': True, 'n_iter_no_change': 15}
# 	[975]: 0.419 (+/-0.251) for {'alpha': 15.5, 'average': True, 'n_iter_no_change': 16}
# 	[976]: 0.495 (+/-0.299) for {'alpha': 15.5, 'average': False, 'n_iter_no_change': 1}
# 	[977]: 0.524 (+/-0.365) for {'alpha': 15.5, 'average': False, 'n_iter_no_change': 2}
# 	[978]: 0.610 (+/-0.434) for {'alpha': 15.5, 'average': False, 'n_iter_no_change': 3}
# 	[979]: 0.505 (+/-0.322) for {'alpha': 15.5, 'average': False, 'n_iter_no_change': 4}
# 	[980]: 0.533 (+/-0.272) for {'alpha': 15.5, 'average': False, 'n_iter_no_change': 5}
# 	[981]: 0.571 (+/-0.356) for {'alpha': 15.5, 'average': False, 'n_iter_no_change': 6}
# 	[982]: 0.410 (+/-0.211) for {'alpha': 15.5, 'average': False, 'n_iter_no_change': 7}
# 	[983]: 0.495 (+/-0.301) for {'alpha': 15.5, 'average': False, 'n_iter_no_change': 8}
# 	[984]: 0.686 (+/-0.058) for {'alpha': 15.5, 'average': False, 'n_iter_no_change': 9}
# 	[985]: 0.629 (+/-0.249) for {'alpha': 15.5, 'average': False, 'n_iter_no_change': 10}
# 	[986]: 0.438 (+/-0.251) for {'alpha': 15.5, 'average': False, 'n_iter_no_change': 11}
# 	[987]: 0.581 (+/-0.355) for {'alpha': 15.5, 'average': False, 'n_iter_no_change': 12}
# 	[988]: 0.552 (+/-0.361) for {'alpha': 15.5, 'average': False, 'n_iter_no_change': 13}
# 	[989]: 0.619 (+/-0.269) for {'alpha': 15.5, 'average': False, 'n_iter_no_change': 14}
# 	[990]: 0.590 (+/-0.222) for {'alpha': 15.5, 'average': False, 'n_iter_no_change': 15}
# 	[991]: 0.638 (+/-0.162) for {'alpha': 15.5, 'average': False, 'n_iter_no_change': 16}
# 	[992]: 0.410 (+/-0.214) for {'alpha': 16.0, 'average': True, 'n_iter_no_change': 1}
# 	[993]: 0.524 (+/-0.293) for {'alpha': 16.0, 'average': True, 'n_iter_no_change': 2}
# 	[994]: 0.438 (+/-0.276) for {'alpha': 16.0, 'average': True, 'n_iter_no_change': 3}
# 	[995]: 0.505 (+/-0.254) for {'alpha': 16.0, 'average': True, 'n_iter_no_change': 4}
# 	[996]: 0.562 (+/-0.380) for {'alpha': 16.0, 'average': True, 'n_iter_no_change': 5}
# 	[997]: 0.629 (+/-0.274) for {'alpha': 16.0, 'average': True, 'n_iter_no_change': 6}
# 	[998]: 0.619 (+/-0.269) for {'alpha': 16.0, 'average': True, 'n_iter_no_change': 7}
# 	[999]: 0.419 (+/-0.300) for {'alpha': 16.0, 'average': True, 'n_iter_no_change': 8}
# 	[1000]: 0.438 (+/-0.248) for {'alpha': 16.0, 'average': True, 'n_iter_no_change': 9}
# 	[1001]: 0.619 (+/-0.269) for {'alpha': 16.0, 'average': True, 'n_iter_no_change': 10}
# 	[1002]: 0.495 (+/-0.266) for {'alpha': 16.0, 'average': True, 'n_iter_no_change': 11}
# 	[1003]: 0.371 (+/-0.016) for {'alpha': 16.0, 'average': True, 'n_iter_no_change': 12}
# 	[1004]: 0.514 (+/-0.249) for {'alpha': 16.0, 'average': True, 'n_iter_no_change': 13}
# 	[1005]: 0.486 (+/-0.279) for {'alpha': 16.0, 'average': True, 'n_iter_no_change': 14}
# 	[1006]: 0.524 (+/-0.278) for {'alpha': 16.0, 'average': True, 'n_iter_no_change': 15}
# 	[1007]: 0.419 (+/-0.279) for {'alpha': 16.0, 'average': True, 'n_iter_no_change': 16}
# 	[1008]: 0.619 (+/-0.243) for {'alpha': 16.0, 'average': False, 'n_iter_no_change': 1}
# 	[1009]: 0.495 (+/-0.322) for {'alpha': 16.0, 'average': False, 'n_iter_no_change': 2}
# 	[1010]: 0.610 (+/-0.261) for {'alpha': 16.0, 'average': False, 'n_iter_no_change': 3}
# 	[1011]: 0.676 (+/-0.052) for {'alpha': 16.0, 'average': False, 'n_iter_no_change': 4}
# 	[1012]: 0.667 (+/-0.181) for {'alpha': 16.0, 'average': False, 'n_iter_no_change': 5}
# 	[1013]: 0.438 (+/-0.276) for {'alpha': 16.0, 'average': False, 'n_iter_no_change': 6}
# 	[1014]: 0.619 (+/-0.330) for {'alpha': 16.0, 'average': False, 'n_iter_no_change': 7}
# 	[1015]: 0.676 (+/-0.194) for {'alpha': 16.0, 'average': False, 'n_iter_no_change': 8}
# 	[1016]: 0.695 (+/-0.031) for {'alpha': 16.0, 'average': False, 'n_iter_no_change': 9}
# 	[1017]: 0.543 (+/-0.311) for {'alpha': 16.0, 'average': False, 'n_iter_no_change': 10}
# 	[1018]: 0.543 (+/-0.335) for {'alpha': 16.0, 'average': False, 'n_iter_no_change': 11}
# 	[1019]: 0.629 (+/-0.251) for {'alpha': 16.0, 'average': False, 'n_iter_no_change': 12}
# 	[1020]: 0.505 (+/-0.254) for {'alpha': 16.0, 'average': False, 'n_iter_no_change': 13}
# 	[1021]: 0.438 (+/-0.251) for {'alpha': 16.0, 'average': False, 'n_iter_no_change': 14}
# 	[1022]: 0.600 (+/-0.243) for {'alpha': 16.0, 'average': False, 'n_iter_no_change': 15}
# 	[1023]: 0.657 (+/-0.224) for {'alpha': 16.0, 'average': False, 'n_iter_no_change': 16}
# 	[1024]: 0.495 (+/-0.280) for {'alpha': 16.5, 'average': True, 'n_iter_no_change': 1}
# 	[1025]: 0.505 (+/-0.322) for {'alpha': 16.5, 'average': True, 'n_iter_no_change': 2}
# 	[1026]: 0.543 (+/-0.311) for {'alpha': 16.5, 'average': True, 'n_iter_no_change': 3}
# 	[1027]: 0.505 (+/-0.340) for {'alpha': 16.5, 'average': True, 'n_iter_no_change': 4}
# 	[1028]: 0.505 (+/-0.322) for {'alpha': 16.5, 'average': True, 'n_iter_no_change': 5}
# 	[1029]: 0.467 (+/-0.315) for {'alpha': 16.5, 'average': True, 'n_iter_no_change': 6}
# 	[1030]: 0.381 (+/-0.082) for {'alpha': 16.5, 'average': True, 'n_iter_no_change': 7}
# 	[1031]: 0.657 (+/-0.087) for {'alpha': 16.5, 'average': True, 'n_iter_no_change': 8}
# 	[1032]: 0.429 (+/-0.238) for {'alpha': 16.5, 'average': True, 'n_iter_no_change': 9}
# 	[1033]: 0.505 (+/-0.260) for {'alpha': 16.5, 'average': True, 'n_iter_no_change': 10}
# 	[1034]: 0.524 (+/-0.301) for {'alpha': 16.5, 'average': True, 'n_iter_no_change': 11}
# 	[1035]: 0.476 (+/-0.276) for {'alpha': 16.5, 'average': True, 'n_iter_no_change': 12}
# 	[1036]: 0.581 (+/-0.348) for {'alpha': 16.5, 'average': True, 'n_iter_no_change': 13}
# 	[1037]: 0.505 (+/-0.322) for {'alpha': 16.5, 'average': True, 'n_iter_no_change': 14}
# 	[1038]: 0.505 (+/-0.342) for {'alpha': 16.5, 'average': True, 'n_iter_no_change': 15}
# 	[1039]: 0.524 (+/-0.296) for {'alpha': 16.5, 'average': True, 'n_iter_no_change': 16}
# 	[1040]: 0.695 (+/-0.296) for {'alpha': 16.5, 'average': False, 'n_iter_no_change': 1}
# 	[1041]: 0.610 (+/-0.417) for {'alpha': 16.5, 'average': False, 'n_iter_no_change': 2}
# 	[1042]: 0.600 (+/-0.437) for {'alpha': 16.5, 'average': False, 'n_iter_no_change': 3}
# 	[1043]: 0.581 (+/-0.348) for {'alpha': 16.5, 'average': False, 'n_iter_no_change': 4}
# 	[1044]: 0.495 (+/-0.301) for {'alpha': 16.5, 'average': False, 'n_iter_no_change': 5}
# 	[1045]: 0.505 (+/-0.250) for {'alpha': 16.5, 'average': False, 'n_iter_no_change': 6}
# 	[1046]: 0.571 (+/-0.330) for {'alpha': 16.5, 'average': False, 'n_iter_no_change': 7}
# 	[1047]: 0.590 (+/-0.234) for {'alpha': 16.5, 'average': False, 'n_iter_no_change': 8}
# 	[1048]: 0.648 (+/-0.089) for {'alpha': 16.5, 'average': False, 'n_iter_no_change': 9}
# 	[1049]: 0.562 (+/-0.317) for {'alpha': 16.5, 'average': False, 'n_iter_no_change': 10}
# 	[1050]: 0.562 (+/-0.317) for {'alpha': 16.5, 'average': False, 'n_iter_no_change': 11}
# 	[1051]: 0.571 (+/-0.337) for {'alpha': 16.5, 'average': False, 'n_iter_no_change': 12}
# 	[1052]: 0.419 (+/-0.200) for {'alpha': 16.5, 'average': False, 'n_iter_no_change': 13}
# 	[1053]: 0.600 (+/-0.253) for {'alpha': 16.5, 'average': False, 'n_iter_no_change': 14}
# 	[1054]: 0.571 (+/-0.365) for {'alpha': 16.5, 'average': False, 'n_iter_no_change': 15}
# 	[1055]: 0.562 (+/-0.337) for {'alpha': 16.5, 'average': False, 'n_iter_no_change': 16}
#
# Detailed classification report:
# 	The model is trained on the full development set.
# 	The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       0.00      0.00      0.00        18
#            2       0.38      1.00      0.55        11
#
#    micro avg       0.60      0.60      0.60        45
#    macro avg       0.46      0.67      0.52        45
# weighted avg       0.45      0.60      0.49        45
#
#
# CTOR for best model: SGDClassifier(alpha=0.5, average=True, class_weight=None,
#        early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#        l1_ratio=0.15, learning_rate='optimal', loss='hinge', max_iter=None,
#        n_iter=None, n_iter_no_change=4, n_jobs=None, penalty='l2',
#        power_t=0.5, random_state=None, shuffle=True, tol=None,
#        validation_fraction=0.1, verbose=0, warm_start=False)
#
# best: dat=iris, score=0.75238, model=SGDClassifier(alpha=0.5,average=True,n_iter_no_change=4)
#
# OK
# D:\programmer\anaconda\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# D:\programmer\anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### Qc Hyperparameter Random  Search using an SDG classifier
#
# Now, add code to run a `RandomizedSearchCV` instead.
#
# <img src="Figs/randomsearch.png" style="width:300px">
# <small><em>
#     <center> Conceptual graphical view of randomized search for two distinct hyperparameters. </center>
# </em></small>
#
# Use the same parameters for the random search, but add and investigate the new `n_iter` parameter
#
# ```python
# random_tuned = RandomizedSearchCV(model, tuning_parameters, random_state=42, n_iter=20, cv=CV, scoring='f1_micro', verbose=VERBOSE, n_jobs=-1, iid=True)
# ```
#
# Comparison of time (seconds) to complete `GridSearch` versus `RandomizedSearchCV`, does not necessarily give any sense, if your grid search completes in seconds (for the iris tiny-data).
#
# But you could compare the best-tuned parameter set and best scoring for the two methods. Is the random search best model close to the grid search?

# %%
# TODO: Qc..

# %% [markdown]
# ### Qd Search Quest
#
# Finally, we create a small competition: who can find the best model+hyperparameters for MNIST dataset?
#
# You change to the MNIST data by calling `LoadAndSetupData('mnist')`, and this is a completely other ball-game that the _tiny-data_ iris: it's much larger (but still far from _big-data_)!
#
# * You might opt for an exhaustive grid search, or a faster but-less optimal random search...your choice.
#
# * You are free to pick any classifier in Scikit-learn, even algorithms we have not discussed yet, but keep the score function at `f1_micro`, otherwise, we will be comparing 'æbler og pærer'.
#
# * And, you may also want to scale you input data for some models to perform better (neural networks in particular).
#
# * DO NOT USE Keras or Tensorflow models...not yet, and there are too many examples on the net to cut-and-paste from!
#
# Check your result by printing the first _return_ value from `FullReport()`
# ```python
# b1, m1 = FullReport(random_tuned , X_test, y_test, time_randomsearch)
# print(b1)
# ```
# that will display a result like
# ```
# best: dat=iris, score=0.97143, model=SVC(C=1, kernel='linear')
# ```
# Now, check if your score (for MNIST) is better that the currently best score on Blackboard: "L07: Optimization and searching" | "Search Quest for MNIST"
#
# > https://blackboard.au.dk/webapps/blackboard/content/listContentEditable.jsp?content_id=_2117394_1&course_id=_124256_1&content_id=_2179138_1
#
# and paste your best model into the message box, like
# ```
# best(Mr.Itmal): dat=mnist, score=0.47090, model=MLPClassifier(random_state=42, max_iter=10, activation='tanh')
# ```
# Remember to provide a _custom_ name manually, like 'best(joe)', 'best(john)' or 'best(it256)', so we can identify a winnner!
#
# For the journal, report your progress in scoring choosing different models, hyperparameters to search and how you might need to preprocess your data...

# %%
# TODO: Qd..
